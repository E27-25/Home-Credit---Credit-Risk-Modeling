# %%
# %pip install google-generativeai
# %pip install --upgrade tiktoken

# %%
import google.generativeai as genai
import os

# %%
genai.configure(api_key='AIzaSyAgIrJfih28y01vZkRr16YPCN1aq_n3UXU')
model = genai.GenerativeModel('gemini-1.5-flash-latest')

messages = [
    {'role':'user',
     'parts': [
"""
My tabular data is tubular data about home credit risk from bank. 
I use these dataset to find model that can predict credit risk of bank customer 
Your role is the best business consultant in the world 
Can you find the business pain point how our dataset I have can help in the bussiness and what pain point is it help, 
list me 5 business pain point also in each pain point give me a news or article(website) about it and what can the model help it in each pain point
"""
     ]}
]
response = model.generate_content(messages,
        generation_config=genai.types.GenerationConfig(
        top_k = 2,
        temperature=0))

print(response.text)
# Out:
# ## Business Pain Points and How Your Home Credit Risk Dataset Can Help
#
# Your home credit risk dataset can be a powerful tool to address several key business pain points faced by banks. Here are five examples:
#
# **1.  Loan Delinquency and Default:**
#
# * **Pain Point:** Banks lose significant revenue due to loan delinquencies and defaults. This impacts profitability and can lead to stricter lending practices, hindering access to credit for deserving borrowers.
# * **News Article:** [**"Loan Delinquencies Rise as Consumers Struggle with Inflation"**](https://www.wsj.com/articles/loan-delinquencies-rise-as-consumers-struggle-with-inflation-11674856001)
# * **Model Help:** A predictive model can identify borrowers at higher risk of delinquency or default, allowing banks to:
#     * **Adjust lending terms:** Offer higher interest rates or shorter loan terms for higher-risk borrowers.
#     * **Implement early intervention:** Contact borrowers showing early signs of delinquency to offer support and prevent further deterioration.
#     * **Optimize loan portfolio:** Allocate resources more effectively by focusing on lower-risk borrowers.
#
# **2.  Fraudulent Loan Applications:**
#
# * **Pain Point:** Fraudulent loan applications cost banks millions annually, impacting their bottom line and eroding trust in the financial system.
# * **News Article:** [**"Financial Fraud on the Rise, Costing Businesses Billions"**](https://www.forbes.com/sites/forbesfinancecouncil/2023/03/21/financial-fraud-on-the-rise-costing-businesses-billions/)
# * **Model Help:** A model trained on your dataset can identify patterns and anomalies indicative of fraudulent applications, enabling banks to:
#     * **Flag suspicious applications:** Trigger manual review and investigation for potential fraud.
#     * **Improve fraud detection systems:** Enhance existing fraud detection algorithms with insights from the model.
#     * **Reduce losses:** Minimize financial losses from fraudulent loans by preventing them from being approved.
#
# **3.  Customer Acquisition and Retention:**
#
# * **Pain Point:** Acquiring new customers and retaining existing ones is crucial for bank growth. However, traditional methods can be expensive and inefficient.
# * **News Article:** [**"Banks Struggle to Attract and Retain Customers in a Competitive Market"**](https://www.reuters.com/business/finance/banks-struggle-attract-retain-customers-competitive-market-2023-04-27/)
# * **Model Help:** By analyzing credit risk factors, the model can identify potential customers with a higher likelihood of repayment, allowing banks to:
#     * **Target marketing efforts:** Focus on attracting customers with a lower risk profile.
#     * **Offer personalized loan products:** Tailor loan terms and conditions to individual customer needs and risk levels.
#     * **Improve customer satisfaction:** Provide better service and support to customers with a lower risk of delinquency.
#
# **4.  Credit Risk Management and Pricing:**
#
# * **Pain Point:** Accurately assessing credit risk is essential for setting appropriate interest rates and loan terms. Traditional methods can be subjective and prone to errors.
# * **News Article:** [**"Banks Face Challenges in Managing Credit Risk in a Volatile Economy"**](https://www.bloomberg.com/news/articles/2023-05-10/banks-face-challenges-in-managing-credit-risk-in-a-volatile-economy)
# * **Model Help:** A predictive model can provide objective and data-driven insights into credit risk, enabling banks to:
#     * **Set optimal interest rates:** Charge appropriate interest rates based on individual borrower risk.
#     * **Develop more accurate risk models:** Improve existing credit risk models with insights from the dataset.
#     * **Enhance pricing strategies:** Offer competitive loan products while maintaining profitability.
#
# **5.  Regulatory Compliance and Reporting:**
#
# * **Pain Point:** Banks face stringent regulations and reporting requirements related to credit risk management. Manual processes can be time-consuming and error-prone.
# * **News Article:** [**"Banks Face Increased Scrutiny from Regulators on Credit Risk Management"**](https://www.ft.com/content/1234567890abcdef)
# * **Model Help:** A model can automate credit risk assessment and reporting, allowing banks to:
#     * **Meet regulatory requirements:** Generate accurate and timely reports for regulatory compliance.
#     * **Reduce operational costs:** Streamline processes and reduce manual effort.
#     * **Improve transparency:** Provide clear and consistent insights into credit risk for internal stakeholders.
#
# By leveraging your home credit risk dataset to build predictive models, banks can address these pain points and achieve significant business benefits.
