# %%
#%pip install google-generativeai

# %%
#%pip install tiktoken

# %%
import pandas as pd

df_train = pd.read_csv('KBTG_train_test\df_train_kbtg_1.csv')
cut_fea = ['lastdelinqdate_224D',
'datelastinstal40dpd_247D',
'pmtssum_45A',
'pmtaverage_3A',
'dateofcredstart_739D',
'refreshdate_3813885D',
'dateofcredstart_181D',
'lastupdate_1112D',
'numberofoverdueinstlmaxdat_148D']

df_train = df_train.drop(cut_fea, axis=1)
# Out:
# C:\Users\msi\AppData\Local\Temp\ipykernel_25716\3050114937.py:3: DtypeWarning: Columns (15,33,41,42,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train = pd.read_csv('KBTG_train_test\df_train_kbtg_1.csv')

# %%
text = f"""
I am working on a dataset from the Home Credit - Credit Risk Modeling Hackathon. This dataset contains various features related to credit applications, including applicant information, loan details, and payment histories. However, some of the entries in this dataset have missing or null values.

Could you help me by handle and fill these null values for each feature(columns) by analytic data? The goal is to create a dataset that is as complete as possible for accurate credit risk modeling. Here are some specific points to consider:

Here is a sample of the dataset feature description for reference:

amount_416A: Deposit amount.
this is example of amount_416A value:
{df_train['amount_416A'].dropna().tolist()[:50]}

avgdpdtolclosure24_3658938P: Average DPD (days past due) with tolerance within the past 24 months from the maximum closure date, assuming that the contract is finished. If the contract is ongoing, the calculation is based on the current date.
this is example of avgdpdtolclosure24_3658938P value:
{df_train['avgdpdtolclosure24_3658938P'].dropna().tolist()[:50]}

cntpmts24_3658933L: Number of months with any incoming payment in last 24 months.
this is example of cntpmts24_3658933L value:
{df_train['cntpmts24_3658933L'].dropna().tolist()[:50]}

days120_123L: Number of credit bureau queries for the last 120 days.
this is example of days120_123L value:
{df_train['days120_123L'].dropna().tolist()[:50]}

days180_256L: Number of credit bureau queries for last 180 days.
this is example of days180_256L value:
{df_train['days180_256L'].dropna().tolist()[:50]}

days30_165L: Number of credit bureau queries for the last 30 days.
this is example of days30_165L value:
{df_train['days30_165L'].dropna().tolist()[:50]}

days360_512L: Number of Credit Bureau queries for last 360 days.
this is example of days360_512L value:
{df_train['days360_512L'].dropna().tolist()[:50]}

description_351M: Categorization of clients by credit bureau.
this is example of description_351M value:
{df_train['description_351M'].dropna().tolist()[:50]}

dpdmax_139P: Maximal days past due for active contract.
this is example of dpdmax_139P value:
{df_train['dpdmax_139P'].dropna().tolist()[:50]}

dpdmax_757P: Maximum days past due for a closed contract.
this is example of dpdmax_757P value:
{df_train['dpdmax_757P'].dropna().tolist()[:50]}

dpdmaxdateyear_596T: Year when maximum Days Past Due (DPD) occurred for the active contract.
this is example of dpdmaxdateyear_596T value:
{df_train['dpdmaxdateyear_596T'].dropna().tolist()[:50]}

education_1103M: Level of education of the client provided by external source.
this is example of education_1103M value:
{df_train['education_1103M'].dropna().tolist()[:50]}

education_927M: Education level of the person.
this is example of education_927M value:
{df_train['education_927M'].dropna().tolist()[:50]}

eir_270L: Interest rate.
this is example of eir_270L value:
{df_train['eir_270L'].dropna().tolist()[:50]}

empladdr_district_926M: District where the employer's address is located.
this is example of empladdr_district_926M value:
{df_train['empladdr_district_926M'].dropna().tolist()[:50]}

firstquarter_103L: Number of results obtained from credit bureau in the first quarter.
this is example of firstquarter_103L value:
{df_train['firstquarter_103L'].dropna().tolist()[:50]}

housetype_905L: House type of the person.
this is example of housetype_905L value:
{df_train['housetype_905L'].dropna().tolist()[:50]}

incometype_1044T: Type of income of the person.
this is example of incometype_1044T value:
{df_train['incometype_1044T'].dropna().tolist()[:50]}

last180dayaveragebalance_704A: Average balance on debit card in the last 180 days.
this is example of last180dayaveragebalance_704A value:
{df_train['last180dayaveragebalance_704A'].dropna().tolist()[:50]}

last180dayturnover_1134A: Debit card's turnover within the last 180 days.
this is example of last180dayturnover_1134A value:
{df_train['last180dayturnover_1134A'].dropna().tolist()[:50]}

last30dayturnover_651A: Debit card turnover for the last 30 days.
this is example of last30dayturnover_651A value:
{df_train['last30dayturnover_651A'].dropna().tolist()[:50]}

lastrejectreason_759M: Reason for rejection on the most recent rejected application.
this is example of lastrejectreason_759M value:
{df_train['lastrejectreason_759M'].dropna().tolist()[:50]}

mainoccupationinc_384A: Amount of the main income of the client.
this is example of mainoccupationinc_384A value:
{df_train['mainoccupationinc_384A'].dropna().tolist()[:50]}

maxdbddpdtollast12m_3658940P: Maximum number of days past due in last 12 months. A negative value implies days before due date.
this is example of maxdbddpdtollast12m_3658940P value:
{df_train['maxdbddpdtollast12m_3658940P'].dropna().tolist()[:50]}

maxdpdlast3m_392P: Maximum number of days past due in last 3 months.
this is example of maxdpdlast3m_392P value:
{df_train['maxdpdlast3m_392P'].dropna().tolist()[:50]}

mobilephncnt_593L: Number of persons with the same mobile phone number.
this is example of mobilephncnt_593L value:
{df_train['mobilephncnt_593L'].dropna().tolist()[:50]}

monthsannuity_845L: Monthly annuity amount for the applicant.
this is example of monthsannuity_845L value:
{df_train['monthsannuity_845L'].dropna().tolist()[:50]}

numberofcontrsvalue_258L: Number of active contracts in credit bureau.
this is example of numberofcontrsvalue_258L value:
{df_train['numberofcontrsvalue_258L'].dropna().tolist()[:50]}

numberofinstls_320L: Number of instalments of the active contract.
this is example of numberofinstls_320L value:
{df_train['numberofinstls_320L'].dropna().tolist()[:50]}

numberofoverdueinstlmax_1039L: Number of outstanding instalments for active contracts.
this is example of numberofoverdueinstlmax_1039L value:
{df_train['numberofoverdueinstlmax_1039L'].dropna().tolist()[:50]}

numincomingpmts_3546848L: Number of incoming payments.
this is example of numincomingpmts_3546848L value:
{df_train['numincomingpmts_3546848L'].dropna().tolist()[:50]}

numinstlsallpaid_934L: Number of paid instalments.
this is example of numinstlsallpaid_934L value:
{df_train['numinstlsallpaid_934L'].dropna().tolist()[:50]}

numinstunpaidmax_3546851L: Maximum number of unpaid instalments.
this is example of numinstunpaidmax_3546851L value:
{df_train['numinstunpaidmax_3546851L'].dropna().tolist()[:50]}

numrejects9m_859L: Number of credit applications that were rejected in the last 9 months.
this is example of numrejects9m_859L value:
{df_train['numrejects9m_859L'].dropna().tolist()[:50]}

overdueamountmax_35A: Maximal past due amount for a closed contract.
this is example of overdueamountmax_35A value:
{df_train['overdueamountmax_35A'].dropna().tolist()[:50]}

overdueamountmax2_14A: Maximal past due amount for an active contract.
this is example of overdueamountmax2_14A value:
{df_train['overdueamountmax2_14A'].dropna().tolist()[:50]}

overdueamountmax2_398A: Maximal overdue amount for a closed contract.
this is example of overdueamountmax2_398A value:
{df_train['overdueamountmax2_398A'].dropna().tolist()[:50]}

pctinstlsallpaidlate1d_3546856L: Percentage of installments that are paid 1 or more days after the due date.
this is example of pctinstlsallpaidlate1d_3546856L value:
{df_train['pctinstlsallpaidlate1d_3546856L'].dropna().tolist()[:50]}

pmtnum_254L: Total number of loan payments made by the client.
this is example of pmtnum_254L value:
{df_train['pmtnum_254L'].dropna().tolist()[:50]}

price_1097A: Credit price.
this is example of price_1097A value:
{df_train['price_1097A'].dropna().tolist()[:50]}

registaddr_district_1083M: District of person's registered address.
this is example of registaddr_district_1083M value:
{df_train['registaddr_district_1083M'].dropna().tolist()[:50]}

residualamount_856A: Residual amount for the active contract.
this is example of residualamount_856A value:
{df_train['residualamount_856A'].dropna().tolist()[:50]}

riskassesment_302T: Estimated probability that the client will default on their credit obligation within the next year.
this is example of riskassesment_302T value:
{df_train['riskassesment_302T'].dropna().tolist()[:50]}

riskassesment_940T: Estimate of client's creditworthiness.
this is example of riskassesment_940T value:
{df_train['riskassesment_940T'].dropna().tolist()[:50]}

thirdquarter_1082L: Number of results in third quarter.
this is example of thirdquarter_1082L value:
{df_train['thirdquarter_1082L'].dropna().tolist()[:50]}

totalamount_6A: Total amount of closed contracts.
this is example of totalamount_6A value:
{df_train['totalamount_6A'].dropna().tolist()[:50]}

totalamount_996A: Total amount of active contracts in the credit bureau.
this is example of totalamount_996A value:
{df_train['totalamount_996A'].dropna().tolist()[:50]}

totaldebtoverduevalue_178A: Total amount of past due debt on active contracts.
this is example of totaldebtoverduevalue_178A value:
{df_train['totaldebtoverduevalue_178A'].dropna().tolist()[:50]}

totaloutstanddebtvalue_39A: Total outstanding debt for active contracts in the credit bureau.
this is example of totaloutstanddebtvalue_39A value:
{df_train['totaloutstanddebtvalue_39A'].dropna().tolist()[:50]}

type_25L: Contact type of a person.
this is example of type_25L value:
{df_train['type_25L'].dropna().tolist()[:50]}

ANSWER me which feature is the risk or reason or another feature that can make a bad or good decision for make a decision reject or not.
"""

# %%
from tiktoken._educational import *
from tqdm import tqdm
# Train a BPE tokeniser on a small amount of text
enc = train_simple_encoding()

# Visualise how the GPT-4 encoder encodes text
enc = SimpleBytePairEncoding.from_tiktoken("cl100k_base")
print(len(enc.encode(text)))
# Out:
# The current most common pair is b' ' + b' '
# So we made b'  ' our 257th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
# import collections
# from typing import Optional
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str: str, mergeable_
#
#
# The current most common pair is b'  ' + b'  '
# So we made b'    ' our 258th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
# import collections
# from typing import Optional
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str: str, mergeable_
#
#
# The current most common pair is b'  ' + b' '
# So we made b'   ' our 259th token
# Now the first fifty words in our training data look like:
# ...

# %%
import google.generativeai as genai
import os

genai.configure(api_key='AIzaSyAgIrJfih28y01vZkRr16YPCN1aq_n3UXU')

model = genai.GenerativeModel('gemini-pro')
response = model.generate_content(text)

print(response.text)
# Out:
# Several features may indicate a risk or reason for making a bad or good decision for making a reject or not decision. These features include:
#
# **Risk Factors:**
#
# * **maxdpdlast3m_392P (Maximum number of days past due in last 3 months):** This feature indicates the maximum number of days a client has been past due on their loan payments in the last three months. A higher value for this feature may indicate a higher risk of default.
# * **numinstunpaidmax_3546851L (Maximum number of unpaid installments):** This feature shows the maximum number of unpaid installments a client has had on their loan contracts. A higher value for this feature may indicate a higher risk of default.
# * **dpdmaxdateyear_596T (Year when maximum Days Past Due (DPD) occurred for the active contract):** This feature indicates the year when the maximum DPD occurred for the active loan contract. A more recent year may indicate a higher risk of default.
# ...
